# %%
# Out:
# /var/folders/zg/dk0qffx55tj5q4d2hvpp5m2c0000gn/T/ipykernel_79516/2896969894.py:6: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, start = start, end = end, multi_level_index=False)
# [*********************100%***********************]  1 of 1 completed

# %%
# Out:
#    day_of_week  sum  size  percentage weekday_name
# 0            0  160   888   18.018018       Monday
# 1            1   81   973    8.324769      Tuesday
# 2            2   75   971    7.723996    Wednesday
# 3            3    2   956    0.209205     Thursday
# 4            4  -14   950   -1.473684       Friday

# %%
# Out:
# AAPL Weekday Performance Summary:
# ...
# Monday      :  17.89% average win rate
# Tuesday     :   8.29% average win rate
# Wednesday   :   7.83% average win rate
# Thursday    :   0.12% average win rate
# Friday      :  -1.48% average win rate
# ...

# %%
# Out:
# <Axes: xlabel='year'>
